# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\saah_\Desktop\INSPER\Ciência dos Dados\Projeto1

# %%
dados = pd.read_excel('PlanCD.xlsx')

# %%
dados.shape
# Out:
# (151189, 81)

# %%
#Tem acesso à internet no próprio domícilio(2-sim, 4-não, não aplicável)
#pd.DataFrame(dados.V02322)

# %%
#Microcomputador é utilizado para acessar a Internet(2-sim, 4-não, não aplicável)
#pd.DataFrame(dados.V0232)

# %%
#O acesso à Internet é feito através de sinal de rede celular 3G ou 4G
#pd.DataFrame(dados.V02424)

# %%
#O acesso à Internet é feito por banda larga
#pd.DataFrame(dados.V02426)

# %%
#O acesso à Internet é feito através de conexão discada por linha telefônica
#pd.DataFrame(dados.V02425)

# %%
#Código de situação censitária
#pd.DataFrame(dados.V4105)

# %%
#Faixa do rendimento mensal domiciliar per capita
#pd.DataFrame(dados.V4622)

# %%
df = pd.DataFrame({'Internet': dados.V02322,
                   'PCinternet': dados.V0232,
                   'd3Gou4G': dados.V02424,
                   'Bandalarga': dados.V02426,
                   'Discada': dados.V02425,
                   'Região': dados.V4105,
                   'Renda': dados.V4622})
df
# Out:
#         Bandalarga  Discada  Internet  PCinternet  Região  Renda  d3Gou4G
# 0              NaN      NaN       4.0         NaN       1    4.0      NaN
# 1              NaN      NaN       NaN         NaN       1    NaN      NaN
# 2              2.0      4.0       2.0         2.0       1    4.0      2.0
# 3              2.0      4.0       2.0         2.0       1    4.0      2.0
# 4              NaN      NaN       4.0         NaN       1    6.0      NaN
# 5              2.0      4.0       2.0         2.0       1    5.0      4.0
# 6              NaN      NaN       4.0         NaN       1    2.0      NaN
# 7              NaN      NaN       4.0         NaN       1    4.0      NaN
# 8              2.0      4.0       2.0         2.0       1    4.0      2.0
# 9              NaN      NaN       NaN         NaN       1    NaN      NaN
# 10             2.0      4.0       2.0         2.0       1    5.0      2.0
# 11             2.0      4.0       2.0         2.0       1    6.0      2.0
# ...

# %%
#Como e qual é o tipo de acesso à internet no Brasil, de acordo com a renda e a localização?

# %%
df = df.dropna()

df
# Out:
#         Bandalarga  Discada  Internet  PCinternet  Região  Renda  d3Gou4G
# 2              2.0      4.0       2.0         2.0       1    4.0      2.0
# 3              2.0      4.0       2.0         2.0       1    4.0      2.0
# 5              2.0      4.0       2.0         2.0       1    5.0      4.0
# 8              2.0      4.0       2.0         2.0       1    4.0      2.0
# 10             2.0      4.0       2.0         2.0       1    5.0      2.0
# 11             2.0      4.0       2.0         2.0       1    6.0      2.0
# 13             2.0      4.0       2.0         2.0       1    4.0      2.0
# 15             2.0      4.0       2.0         2.0       1    3.0      2.0
# 18             2.0      4.0       2.0         2.0       1    4.0      4.0
# 19             4.0      2.0       2.0         2.0       1    3.0      4.0
# 20             2.0      4.0       2.0         2.0       1    4.0      4.0
# 27             2.0      4.0       2.0         2.0       1    6.0      4.0
# ...

# %%
df.d3Gou4G = df.d3Gou4G.astype('category')
df.d3Gou4G.cat.categories = (['Sim', 'Não'])
df.Bandalarga = df.Bandalarga.astype('category')
df.Bandalarga.cat.categories = (['Sim', 'Não'])
df.Discada = df.Discada.astype('category')
df.Discada.cat.categories = (['Sim', 'Não'])
#df.Internet = df.Internet.astype('category')
#df.Internet.cat.categories = (['Sim', 'Não'])
#df.PCinternet = df.PCinternet.astype('category')
#df.PCinternet.cat.categories = (['Sim', 'Não'])
#df.Região = df.Região.astype('category')
#df.Região.cat.categories = (['Sim', 'Não'])
#df.Renda = df.Renda.astype('category')
#df.Renda.cat.categories = (['Sim', 'Não'])
df.dtypes
# Out:
# C:\Users\saah_\Anaconda3\lib\site-packages\pandas\core\generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# Bandalarga    category
# Discada       category
# Internet      category
# PCinternet     float64
# Região           int64
# Renda          float64
# d3Gou4G       category
# dtype: object

# %%
df1 = df['Bandalarga'].value_counts()

df1.plot(kind='pie', colors=('yellow', 'salmon'), autopct="%0.2f",legend=True)

# %%
df2 = df['Discada'].value_counts()

df2.plot(kind='pie', colors=('yellow', 'salmon'), autopct="%0.2f",legend=True)

# %%
df3 = df['d3Gou4G'].value_counts()

df3.plot(kind='pie', colors=('yellow', 'salmon'), autopct="%0.2f",legend=True)

# %%
dfc = df['Renda'].value_counts()
dfc.plot(kind='bar', color=('blue', 'red'), legend=False)

# %%
plot = df['Renda'].plot(kind='box',title='Renda').grid()
plt.ylabel('(Frequência)')

# %%
ct1 = pd.crosstab(df['Discada'], df['Bandalarga'])
ct1.plot(kind='bar', color=('yellow', 'salmon'))
df.plt.ylabel('Frequência Absoluta')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-6bacca3dc658> in <module>()
#       1 ct1 = pd.crosstab(df['Discada'], df['Bandalarga'])
#       2 ct1.plot(kind='bar', color=('yellow', 'salmon'))
# ----> 3 df.plt.ylabel('Frequência Absoluta')
#
# C:\Users\saah_\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %%
df1 = (df['Internet']==2)
ct = pd.crosstab(df['Renda'], df1)
ct
